# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::numba==0.41.0=py37h962f231_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::anaconda==2018.12=py37_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/rdhakal2/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           5 KB
#     anaconda-custom            |           py37_1           3 KB
#     pyrsistent-0.15.4          |   py37h516909a_0          89 KB  conda-forge
#     soupsieve-1.9.2            |           py37_0          58 KB  conda-forge
#     tbb-2019.7                 |       hc9558a2_0         1.4 MB  conda-forge
#     zipp-0.5.2                 |             py_0           7 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2019.03-py37_0
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.15.4-py37h516909a_0
#   soupsieve          conda-forge/linux-64::soupsieve-1.9.2-py37_0
#   tbb                conda-forge/linux-64::tbb-2019.7-hc9558a2_0
#   zipp               conda-forge/noarch::zipp-0.5.2-py_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2018.12-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
# zipp-0.5.2           | 7 KB      | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# _anaconda_depends-20 | 5 KB      | ##################################### | 100%
# pyrsistent-0.15.4    | 89 KB     | ##################################### | 100%
# soupsieve-1.9.2      | 58 KB     | ##################################### | 100%
# tbb-2019.7           | 1.4 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/rdhakal2/anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     setuptools-40.6.3          |           py37_0         612 KB  conda-forge
#     wheel-0.32.3               |           py37_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         646 KB
#
# The following packages will be UPDATED:
#
#   anaconda                                    custom-py37_1 --> 2018.12-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   bzip2                 conda-forge::bzip2-1.0.8-h516909a_0 --> pkgs/main::bzip2-1.0.6-h14c3975_5
#   ca-certificates    conda-forge::ca-certificates-2019.6.1~ --> pkgs/main::ca-certificates-2018.03.07-0
#   certifi             conda-forge::certifi-2019.6.16-py37_1 --> pkgs/main::certifi-2018.11.29-py37_0
#   libffi             conda-forge::libffi-3.2.1-he1b5a44_10~ --> pkgs/main::libffi-3.2.1-hd88cf55_4
#   ncurses            conda-forge::ncurses-6.1-hf484d3e_1002 --> pkgs/main::ncurses-6.1-he6710b0_1
#   openssl            conda-forge::openssl-1.1.1c-h516909a_0 --> pkgs/main::openssl-1.1.1a-h7b6447c_0
#   pip                        conda-forge::pip-19.2.1-py37_0 --> pkgs/main::pip-18.1-py37_0
#   python               conda-forge::python-3.7.3-h33d41f4_1 --> pkgs/main::python-3.7.1-h0371630_7
#   readline             conda-forge::readline-8.0-hf8c457e_0 --> pkgs/main::readline-7.0-h7b6447c_5
#   sqlite              conda-forge::sqlite-3.29.0-hcee41ef_0 --> pkgs/main::sqlite-3.26.0-h7b6447c_0
#   tk                    conda-forge::tk-8.6.9-hed695b0_1002 --> pkgs/main::tk-8.6.8-hbc83047_0
#   xz                    conda-forge::xz-5.2.4-h14c3975_1001 --> pkgs/main::xz-5.2.4-h14c3975_4
#   zlib               conda-forge::zlib-1.2.11-h516909a_1005 --> pkgs/main::zlib-1.2.11-h7b6447c_3
#
# The following packages will be DOWNGRADED:
#
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 8.2.0-hdf63c60_1
#   setuptools                                  41.0.1-py37_0 --> 40.6.3-py37_0
#   wheel                                       0.33.4-py37_0 --> 0.32.3-py37_0
#
#
#
# Downloading and Extracting Packages
# setuptools-40.6.3    | 612 KB    | ##################################### | 100%
# wheel-0.32.3         | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.
